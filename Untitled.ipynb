# %% [markdown]
# Huom: macos Catalina + matplotlib <= 3.2 on ongelmallinen yhdistelmä, käytetään matplotlib 3.3 sourcesta buildattuna

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from prophet.python import fbprophet
from prophet.python.fbprophet import models
from prophet.python.fbprophet import plot
from prophet.python.fbprophet import diagnostics

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pkg_resources
import os
from pathlib import Path
import numpy as np
import scipy
from copy import deepcopy
import tqdm
# Out:
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# # 1. Tutkitaan dataa

# %%
features = pd.read_csv('data/Features data set.csv')
features['Date'] = pd.to_datetime(features['Date'], dayfirst=True)
sales = pd.read_csv('data/sales data-set.csv')
sales['Date'] = pd.to_datetime(sales['Date'], dayfirst=True)

# %% [raw]
# features.groupby('Date').aggregate(lambda r: r.isna().sum()).sort_values(by='Date').tail(20)

# %% [raw]
# features[features['Date'] == '2013-04-26']

# %%
for f in features.columns.drop(['Store', 'Date', 'IsHoliday']):
    features.pivot(columns='Store', index='Date', values=f).plot(legend=False).set_ylabel(f);

# %%
sales.groupby('Date').sum().plot(y='Weekly_Sales', legend=False);

# %%
sales.groupby(['Store', 'Date']).sum().reset_index().pivot(index='Date', columns='Store', values='Weekly_Sales').plot(legend=False);

# %%
def lppd(model):
    return np.log(np.exp(model.params['log_lik']).mean(axis=0)).sum()


def aic(model):
    k = model.params['beta'].shape[1] + model.params['delta'].shape[1] + 2
    return -2*lppd(model) + 2*k


def log_lik_bayes_theta(model):
    mu = model.predict()['yhat']/model.y_scale
    y = model.history['y']/model.y_scale
    sigma = model.params['sigma_obs'].mean()
    return scipy.stats.norm.logpdf(y, loc=mu, scale=sigma).sum()


def dic(model):  # Vois olla nopeempi, nyt log_lik_bayes laskettu kahdesti
    return -2*log_lik_bayes_theta(model) + 2*p_dic(model)


def dic_alt(model):
    return -2*log_lik_bayes_theta(model) + 2*p_dic_alt(model)


def waic(model):
    #ll = model.params['log_lik']
    #pwaic2 = 1/(model.mcmc_samples - 1)*((ll - ll.mean(axis=0))**2).sum(axis=0).sum()
    return -2*lppd(model) + 2*p_waic_2(model)

def loo_cv(model):
    k = model.history.shape[0]
    return k_fold_loo_cv(model, k)

def k_fold_loo_cv(model, k=10):  # Oletetaan, että residuaalit iid
    og_lppd = lppd(model)
    data = model.history.sample(frac=1)  # shuffle
    breakpoints = np.linspace(0, data.shape[0], k+1, endpoint=True).astype(int)
    
    #scipy.stats.norm.pdf(p, loc=df['y'].values, scale=m1.params['sigma_obs'][:, np.newaxis])  # TODO: muista skaalaus
    def train_test_split(i):
        test = data[breakpoints[i]:breakpoints[i+1]].sort_values(by='t').reset_index().drop(columns='index')
        train = data.drop(test.index, axis=0).sort_values(by='t').reset_index().drop(columns='index')
        return (train, test) 
    
    res = 0
    lppd_i = 0
    for i in tqdm.tqdm(range(k)):
        train, test = train_test_split(i)
        clean_model = prophet_copy(model)
        fit = clean_model.fit(train)
        p = predict_with_samples(fit, test)
        lik = scipy.stats.norm.pdf(p/fit.y_scale, loc=test['y'].values/fit.y_scale, scale=fit.params['sigma_obs'][:, np.newaxis])
        res += np.log(lik.prod(axis=1).mean())
        
        p_i = predict_with_samples(fit, model.history)
        b_lik = scipy.stats.norm.pdf(p_i/fit.y_scale, loc=model.history['y'].values/fit.y_scale, scale=fit.params['sigma_obs'][:, np.newaxis])
        lppd_i += np.log(b_lik.prod(axis=1).mean())/k
        
    bias = og_lppd - lppd_i
    return {'lppd_loo_cv': res, 'lppd_cloo_cv': res + bias, 'bias': bias, 'p_cloo': lppd_i - res}
    

def prophet_copy(m):
    if m.history is None:
        raise Exception('Mallin täytyy olla eka fitattu originaalilla datalla. CV tulee laskea siis vikana')

    if m.specified_changepoints:
        changepoints = m.changepoints
        #if cutoff is not None:
        #    # Filter change points '<= cutoff'
        #    changepoints = changepoints[changepoints <= cutoff]
    else:
        changepoints = None

    # Auto seasonalities are set to False because they are already set in
    # m.seasonalities.
    m2 = m.__class__(
        growth=m.growth,
        n_changepoints=m.n_changepoints,
        changepoint_range=m.changepoint_range,
        changepoints=changepoints,
        yearly_seasonality=False,
        weekly_seasonality=False,
        daily_seasonality=False,
        holidays=m.holidays,
        seasonality_mode=m.seasonality_mode,
        seasonality_prior_scale=m.seasonality_prior_scale,
        changepoint_prior_scale=m.changepoint_prior_scale,
        holidays_prior_scale=m.holidays_prior_scale,
        mcmc_samples=m.mcmc_samples,
        interval_width=m.interval_width,
        uncertainty_samples=m.uncertainty_samples,
        stan_backend=m.stan_backend.get_type()
    )
    m2.extra_regressors = deepcopy(m.extra_regressors)
    m2.seasonalities = deepcopy(m.seasonalities)
    m2.country_holidays = deepcopy(m.country_holidays)
    return m2    
    
    
def predict_with_samples(model, df):
    """
    In: model, prediction df
    Out: s*n matrix of predictions
    """
    
    trend = predict_trend_with_samples(model, df)
    sf = predict_seasonal_components_with_samples(model, df)
    return trend * (1 + sf['multiplicative_terms']) + sf['additive_terms']
    


def predict_seasonal_components_with_samples(model, df): # TODO: make_all antaa train setin kokoisen framen ulos
    seasonal_features, _, component_cols, _ = (
        model.make_all_seasonality_features(df)
    )
    X = seasonal_features.values
    data = {}
    for component in component_cols.columns:
        beta_c = model.params['beta'] * component_cols[component].values
        comp = (X @ beta_c.T).T
        if component in model.component_modes['additive']:
            comp *= model.y_scale
        data[component] = comp
    return data
    
def predict_trend_with_samples(model, df):  # TODO: implement also for logistic and flat trends
    #k = np.nanmean(self.params['k'])
    #m = np.nanmean(self.params['m'])
    #deltas = np.nanmean(self.params['delta'], axis=0)

    #t = np.array(df['t'])
    #if self.growth == 'linear':
    #    trend = self.piecewise_linear(t, deltas, k, m, self.changepoints_t)
    #elif self.growth == 'logistic':
    #    cap = df['cap_scaled']
    #    trend = self.piecewise_logistic(
    #        t, cap, deltas, k, m, self.changepoints_t)
    #elif self.growth == 'flat':
    #    # constant trend
    #    trend = self.flat_trend(t, m)
        
    t_cp = model.changepoints_t
    n_cp = t_cp.size
    n = df.shape[0]
    A = np.zeros([n, n_cp])
    for i in range(n):
        A[i, :] = t_cp <= df.iloc[i, :]['t']  # TODO: katso että kumpikin on timestamp tai float
    
    delta = model.params['delta']
    k = model.params['k']
    m = model.params['m']
    
    trend = df['t'].values * (k + A @ delta.T).T + (m + A @ (-t_cp * delta).T).T
    trend *= model.y_scale

    return trend

# %% [raw]
# import sys
# !{sys.executable} -m pip install fbprophet

# %% [raw]
# k_fold_loo_cv(m1, k=20)

# %% [raw]
# k_fold_loo_cv(m1, k=3)

# %%
def p_dic(model):
    return 2*(log_lik_bayes_theta(model) - model.params['log_lik'].sum(axis=1).mean())
              
def p_waic_2(model):
    ll = model.params['log_lik']
    return 1/(model.mcmc_samples - 1)*((ll - ll.mean(axis=0))**2).sum(axis=0).sum()  # Tuplacheckattava

def p_dic_alt(model):  # Pitäis olla oikein
    return model.params['log_lik'].sum(axis=1).var()*2

# %%
def compare_models(ms, data, no_fit=False):
    """Lista malleista ja oikean mallinen df (sis. y, ds, x) -> metriikat malleille.
    Mallit ei saa olla fitattuja."""
    metrics = {'AIC': aic, 'DIC': dic, 'DIC_alt': dic_alt, 'WAIC2': waic, 'p_dic': p_dic, 'p_dic_alt': p_dic_alt, 'p_waic2': p_waic_2, '10-fold_cv': lambda x: k_fold_loo_cv(x, k=10)}
    
    if no_fit:
        fits = ms
    else:
        fits = [m.fit(data) for m in ms]
    for metric_name, metric in metrics.items():
        print(f'Evaluating {metric_name}')
        for f in fits:
            value = metric(f)
            print(value)
        print('')

# %%
# Make dataframe
y = sales.groupby(['Store', 'Date'])['Weekly_Sales'].sum()
y = y.reset_index()
data = y.merge(features, on=['Date', 'Store'], how='left').rename(columns={'Date': 'ds', 'Weekly_Sales': 'y'})
data['overfit'] = data['y']
data1 = data[data['Store'] == 1]

# Initialize models
m1 = fbprophet.Prophet(mcmc_samples=500, seasonality_mode='multiplicative')
m2 = fbprophet.Prophet(mcmc_samples=500, seasonality_mode='additive')
m3 = fbprophet.Prophet(mcmc_samples=500, seasonality_mode='additive')
m4 = fbprophet.Prophet(mcmc_samples=500, yearly_seasonality=50, seasonality_mode='additive')
m5 = fbprophet.Prophet(mcmc_samples=500, yearly_seasonality=False, n_changepoints=1)

for r in ['Temperature', 'Fuel_Price', 'CPI', 'Unemployment']:
    m2.add_regressor(r)
    
m3.add_regressor('overfit')
m5.add_regressor('overfit')

data1.head(5)
# Out:
# Importing plotly failed. Interactive plots will not work.
#    Store         ds           y  Temperature  Fuel_Price  MarkDown1  \
# 0      1 2010-02-05  1643690.90        42.31       2.572        NaN
# 1      1 2010-02-12  1641957.44        38.51       2.548        NaN
# 2      1 2010-02-19  1611968.17        39.93       2.514        NaN
# 3      1 2010-02-26  1409727.59        46.63       2.561        NaN
# 4      1 2010-03-05  1554806.68        46.50       2.625        NaN
#
#    MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0        NaN        NaN        NaN        NaN  211.096358         8.106
# 1        NaN        NaN        NaN        NaN  211.242170         8.106
# 2        NaN        NaN        NaN        NaN  211.289143         8.106
# 3        NaN        NaN        NaN        NaN  211.319643         8.106
# 4        NaN        NaN        NaN        NaN  211.350143         8.106
#
#    IsHoliday     overfit
# 0      False  1643690.90
# 1       True  1641957.44
# 2      False  1611968.17
# 3      False  1409727.59
# 4      False  1554806.68

# %% [raw]
# import logging
# test_logger = logging.getLogger()
# test_logger.setLevel(logging.DEBUG)
# test_logger.addHandler(logging.StreamHandler())
# test_logger.debug('Apua')

# %%
compare_models([m1, m2, m3, m4, m5], data1, no_fit=False)
# Out:
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:712 of 1000 iterations ended with a divergence (71.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:288 of 1000 iterations saturated the maximum tree depth of 10 (28.8 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 2: E-BFMI = 0.126
# WARNING:pystan:Chain 3: E-BFMI = 0.105
# WARNING:pystan:Chain 4: E-BFMI = 0.117
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:89 of 1000 iterations saturated the maximum tree depth of 10 (8.9 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:347 of 1000 iterations ended with a divergence (34.7 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Chain 1: E-BFMI = 0.111
# WARNING:pystan:Chain 2: E-BFMI = 0.0287
# WARNING:pystan:Chain 3: E-BFMI = 0.0389
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# Evaluating AIC
# -384.5329994430283
# -379.05745937868033
# -2806.581977911943
# -555.0326548045982
# -2894.518988327962
#
# Evaluating DIC
# -429.810976401488
# -428.5448071024516
# -2835.30376966691
# -662.6341599515027
# -2898.49393287812
#
# Evaluating DIC_alt
# -410.5526592707999
# -415.0692282493256
# 688.3662586622931
# -109.39602983801763
# 2928.4580074242604
#
# Evaluating WAIC2
# -364.53725288948095
# -357.7542073093608
# -2814.143039097007
# -549.9777319204063
# -2861.419148557678
#
# Evaluating p_dic
# 25.318049591104057
# 27.82253772910343
# 50.66342513444579
# 104.31538151318478
#   0%|          | 0/10 [00:00<?, ?it/s]
# -6.101953828730075
#
# Evaluating p_dic_alt
# 34.94720815644811
# 34.56032715566644
# 1812.4984392990473
# 380.93444656992733
# 2907.37401632246
#
# Evaluating p_waic2
# 56.99787327677368
# 61.65162603465975
# 44.21946940746791
# 129.52746144209593
# 20.549919885141925
#
# Evaluating 10-fold_cv
# 100%|██████████| 10/10 [01:16<00:00,  7.63s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# {'lppd_loo_cv': 235.31385522835282, 'lppd_cloo_cv': 244.288788620583, 'bias': 8.974933392230184, 'p_cloo': -5.022288899068855}
# 100%|██████████| 10/10 [01:37<00:00,  9.73s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# {'lppd_loo_cv': 236.26489264983587, 'lppd_cloo_cv': 245.79471349191277, 'bias': 9.529820842076901, 'p_cloo': -5.265983802572606}
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:627 of 1000 iterations ended with a divergence (62.7 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:373 of 1000 iterations saturated the maximum tree depth of 10 (37.3 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.103
# WARNING:pystan:Chain 4: E-BFMI = 0.0826
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# /Users/leevironty/koodi/kandi/venv/lib/python3.7/site-packages/ipykernel_launcher.py:53: RuntimeWarning: divide by zero encountered in log
# /Users/leevironty/koodi/kandi/venv/lib/python3.7/site-packages/ipykernel_launcher.py:57: RuntimeWarning: divide by zero encountered in log
#  10%|█         | 1/10 [00:36<05:30, 36.68s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:639 of 1000 iterations ended with a divergence (63.9 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:361 of 1000 iterations saturated the maximum tree depth of 10 (36.1 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.114
# WARNING:pystan:Chain 3: E-BFMI = 0.0504
# WARNING:pystan:Chain 4: E-BFMI = 0.189
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  20%|██        | 2/10 [01:12<04:52, 36.53s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:636 of 1000 iterations ended with a divergence (63.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:364 of 1000 iterations saturated the maximum tree depth of 10 (36.4 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.129
# WARNING:pystan:Chain 2: E-BFMI = 0.127
# WARNING:pystan:Chain 4: E-BFMI = 0.0424
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  30%|███       | 3/10 [01:48<04:13, 36.25s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:655 of 1000 iterations ended with a divergence (65.5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:345 of 1000 iterations saturated the maximum tree depth of 10 (34.5 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.0775
# WARNING:pystan:Chain 2: E-BFMI = 0.0774
# WARNING:pystan:Chain 3: E-BFMI = 0.117
# WARNING:pystan:Chain 4: E-BFMI = 0.162
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  40%|████      | 4/10 [02:25<03:38, 36.37s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:611 of 1000 iterations ended with a divergence (61.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:389 of 1000 iterations saturated the maximum tree depth of 10 (38.9 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 2: E-BFMI = 0.114
# WARNING:pystan:Chain 3: E-BFMI = 0.119
# WARNING:pystan:Chain 4: E-BFMI = 0.0393
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  50%|█████     | 5/10 [03:02<03:03, 36.75s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:618 of 1000 iterations ended with a divergence (61.8 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:382 of 1000 iterations saturated the maximum tree depth of 10 (38.2 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 2: E-BFMI = 0.195
# WARNING:pystan:Chain 3: E-BFMI = 0.103
# WARNING:pystan:Chain 4: E-BFMI = 0.051
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  60%|██████    | 6/10 [03:41<02:29, 37.35s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:543 of 1000 iterations ended with a divergence (54.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:457 of 1000 iterations saturated the maximum tree depth of 10 (45.7 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.0543
# WARNING:pystan:Chain 2: E-BFMI = 0.132
# WARNING:pystan:Chain 3: E-BFMI = 0.186
# WARNING:pystan:Chain 4: E-BFMI = 0.0505
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  70%|███████   | 7/10 [04:20<01:53, 37.98s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:625 of 1000 iterations ended with a divergence (62.5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:375 of 1000 iterations saturated the maximum tree depth of 10 (37.5 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.0461
# WARNING:pystan:Chain 4: E-BFMI = 0.134
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  80%|████████  | 8/10 [05:12<01:24, 42.13s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:683 of 1000 iterations ended with a divergence (68.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:317 of 1000 iterations saturated the maximum tree depth of 10 (31.7 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.132
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  90%|█████████ | 9/10 [05:52<00:41, 41.41s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:571 of 1000 iterations ended with a divergence (57.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:429 of 1000 iterations saturated the maximum tree depth of 10 (42.9 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 2: E-BFMI = 0.0458
# WARNING:pystan:Chain 4: E-BFMI = 0.0507
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# 100%|██████████| 10/10 [06:35<00:00, 39.59s/it]
# /Users/leevironty/koodi/kandi/venv/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in double_scalars
#   0%|          | 0/10 [00:00<?, ?it/s]
# {'lppd_loo_cv': -inf, 'lppd_cloo_cv': nan, 'bias': inf, 'p_cloo': nan}
# WARNING:pystan:60 of 1000 iterations saturated the maximum tree depth of 10 (6 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
#  10%|█         | 1/10 [00:49<07:29, 50.00s/it]WARNING:pystan:94 of 1000 iterations saturated the maximum tree depth of 10 (9.4 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
#  20%|██        | 2/10 [01:46<06:56, 52.10s/it]WARNING:pystan:53 of 1000 iterations saturated the maximum tree depth of 10 (5.3 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
#  30%|███       | 3/10 [02:32<05:50, 50.03s/it]WARNING:pystan:123 of 1000 iterations saturated the maximum tree depth of 10 (12.3 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
#  40%|████      | 4/10 [03:22<05:00, 50.09s/it]WARNING:pystan:75 of 1000 iterations saturated the maximum tree depth of 10 (7.5 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
#  50%|█████     | 5/10 [04:17<04:17, 51.54s/it]WARNING:pystan:69 of 1000 iterations saturated the maximum tree depth of 10 (6.9 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
#  60%|██████    | 6/10 [05:14<03:32, 53.20s/it]WARNING:pystan:100 of 1000 iterations saturated the maximum tree depth of 10 (10 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
#  70%|███████   | 7/10 [06:17<02:48, 56.20s/it]WARNING:pystan:7 of 1000 iterations saturated the maximum tree depth of 10 (0.7 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
#  80%|████████  | 8/10 [07:26<01:59, 59.96s/it]WARNING:pystan:86 of 1000 iterations saturated the maximum tree depth of 10 (8.6 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
#  90%|█████████ | 9/10 [08:27<01:00, 60.30s/it]WARNING:pystan:70 of 1000 iterations saturated the maximum tree depth of 10 (7 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# 100%|██████████| 10/10 [09:31<00:00, 57.15s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# {'lppd_loo_cv': 409.9921534699497, 'lppd_cloo_cv': 446.4395544240519, 'bias': 36.44740095410219, 'p_cloo': -41.92322702175278}
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:352 of 1000 iterations ended with a divergence (35.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Chain 1: E-BFMI = 0.034
# WARNING:pystan:Chain 2: E-BFMI = 0.169
# WARNING:pystan:Chain 4: E-BFMI = 0.152
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  10%|█         | 1/10 [00:02<00:18,  2.11s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:339 of 1000 iterations ended with a divergence (33.9 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Chain 1: E-BFMI = 0.15
# WARNING:pystan:Chain 2: E-BFMI = 0.101
# WARNING:pystan:Chain 3: E-BFMI = 0.0603
# WARNING:pystan:Chain 4: E-BFMI = 0.168
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  20%|██        | 2/10 [00:04<00:17,  2.15s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:334 of 1000 iterations ended with a divergence (33.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Chain 2: E-BFMI = 0.0949
# WARNING:pystan:Chain 3: E-BFMI = 0.0265
# WARNING:pystan:Chain 4: E-BFMI = 0.098
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  30%|███       | 3/10 [00:06<00:14,  2.05s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:323 of 1000 iterations ended with a divergence (32.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Chain 1: E-BFMI = 0.046
# WARNING:pystan:Chain 2: E-BFMI = 0.129
# WARNING:pystan:Chain 3: E-BFMI = 0.176
# WARNING:pystan:Chain 4: E-BFMI = 0.117
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  40%|████      | 4/10 [00:07<00:11,  1.94s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:284 of 1000 iterations ended with a divergence (28.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Chain 2: E-BFMI = 0.0399
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  50%|█████     | 5/10 [00:09<00:09,  1.83s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:368 of 1000 iterations ended with a divergence (36.8 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Chain 3: E-BFMI = 0.0487
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  60%|██████    | 6/10 [00:12<00:09,  2.33s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:294 of 1000 iterations ended with a divergence (29.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Chain 3: E-BFMI = 0.0578
# WARNING:pystan:Chain 4: E-BFMI = 0.0234
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  70%|███████   | 7/10 [00:14<00:06,  2.24s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:309 of 1000 iterations ended with a divergence (30.9 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Chain 3: E-BFMI = 0.0375
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  80%|████████  | 8/10 [00:17<00:04,  2.19s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:341 of 1000 iterations ended with a divergence (34.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Chain 1: E-BFMI = 0.0768
# WARNING:pystan:Chain 2: E-BFMI = 0.159
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
#  90%|█████████ | 9/10 [00:18<00:02,  2.10s/it]WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:367 of 1000 iterations ended with a divergence (36.7 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Chain 1: E-BFMI = 0.0466
# WARNING:pystan:Chain 2: E-BFMI = 0.0393
# WARNING:pystan:Chain 3: E-BFMI = 0.125
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# 100%|██████████| 10/10 [00:20<00:00,  2.08s/it]
# {'lppd_loo_cv': -inf, 'lppd_cloo_cv': nan, 'bias': inf, 'p_cloo': nan}

# %%
m = m5
print(m.seasonalities)
print()
print(m.extra_regressors)
print()
print(m.holidays)
# Out:
# OrderedDict()
#
# OrderedDict([('overfit', {'prior_scale': 10.0, 'standardize': 'auto', 'mu': 1555264.3975524476, 'std': 155980.7677611998, 'mode': 'additive'})])
#
# None

# %%
s = m5.params['sigma_obs'].mean()
s
# Out:
# 1.6520215847335744e-05

# %%
scipy.stats.norm.logpdf(0, loc=0, scale=s)*150
# Out:
# 1513.7980786399157

# %%
yhat = predict_with_samples(m5, m5.history)
y = m5.history['y']

# %%
res = yhat - y.values

# %%
lppd(m5)
# Out:
# 1451.259494163981

# %%
s = m5.params['sigma_obs']

# %%
lik = scipy.stats.norm.pdf(res/m5.y_scale, s[:, np.newaxis])
lik
# Out:
# array([[0.39894228, 0.39894228, 0.39894228, ..., 0.39894228, 0.39894228,
#         0.39894228],
#        [0.39894228, 0.39894228, 0.39894228, ..., 0.39894228, 0.39894228,
#         0.39894228],
#        [0.39894228, 0.39894228, 0.39894228, ..., 0.39894228, 0.39894228,
#         0.39894228],
#        ...,
#        [0.39894228, 0.39894228, 0.39894228, ..., 0.39894228, 0.39894228,
#         0.39894228],
#        [0.39894228, 0.39894228, 0.39894228, ..., 0.39894228, 0.39894228,
#         0.39894228],
#        [0.39894228, 0.39894228, 0.39894228, ..., 0.39894228, 0.39894228,
#         0.39894228]])

# %%
np.log(lik.mean(axis=0)).sum()
# Out:
# -131.4082102699865

# %%
np.log(lik.mean(axis=0).prod())
# Out:
# -131.4082102699865

# %%
np.log(lik.prod(axis=1).mean())  # WTF???
# Out:
# -131.4082102699865

# %%
sns.distplot(m1.params['k'][:30])
sns.distplot(m1.params['k'][-30:])
# Out:
# <AxesSubplot:>

# %%
m5.params.keys()
# Out:
# dict_keys(['k', 'm', 'delta', 'sigma_obs', 'beta', 'trend', 'mu', 'log_lik'])

# %%
m1.params['delta'].shape
# Out:
# (1000, 25)

# %%
for i in range(m4.params['beta'].shape[1]):
    sns.kdeplot(m4.params['beta'][:,i])

# %%
-2695.326299541985 + 2877.7078976181633
# Out:
# 182.3815980761783

# %%
-2599.326299541985 + 2869.7078976181633
# Out:
# 270.3815980761783

# %%
def plot_model(model):
    fdf = model.make_future_dataframe(0, freq='W')
    pred = model.predict()
    model.plot(pred);
    model.plot_components(pred);

# %%
plot_model(m5)

# %%
x.merge(y, on='Date')
# Out:
#          Date  Temperature  Fuel_Price         CPI  Weekly_Sales  IsHoliday
# 0  2010-02-19    37.719778    2.672067  167.871686   48276993.78        0.0
# 1  2010-02-26    39.243556    2.683933  167.909657   43968571.13        0.0
# 2  2010-03-12    47.432444    2.774422  167.985598   49909027.88        0.0
# 3  2010-03-19    49.954222    2.817089  167.930427   44988974.64        0.0
# 4  2010-03-26    48.473556    2.824111  167.859731   44133961.05        0.0
# ..        ...          ...         ...         ...           ...        ...
# 91 2012-09-14    70.238222    3.852044  176.110660   44226038.65        0.0
# 92 2012-09-21    67.924889    3.907911  176.242124   44354547.11        0.0
# 93 2012-09-28    68.754444    3.854578  176.373588   43734899.40        0.0
# 94 2012-10-19    60.705333    3.880000  176.652613   45122410.57        0.0
# 95 2012-10-26    61.051111    3.791489  176.649482   45544116.29        0.0
#
# [96 rows x 6 columns]

# %%
sns.distplot(f.params['sigma_obs'])

# %%
s = model.predictive_samples(horizon)

# %%
s
# Out:
# {'yhat': array([[45936640.26217508, 40919498.09019026, 39617351.22720364, ...,
#          44099902.97881629, 49635354.7356011 , 41386745.5931058 ],
#         [49641575.76607701, 58450905.98459424, 46950044.13292231, ...,
#          51782117.11434287, 42246211.02200094, 44041504.93619639],
#         [50245285.48395129, 46189834.22217822, 57402423.02939378, ...,
#          42620708.18451212, 48173412.40833563, 42148615.19466775],
#         ...,
#         [48508106.39356891, 46888799.17885605, 43210019.25158428, ...,
#          36492676.33091234, 49371963.7396779 , 39036829.32641425],
#         [49648592.60230367, 46463664.2930899 , 44799774.85180207, ...,
#          49288024.63958909, 39109689.94976657, 59279651.30161466],
#         [44890161.03233694, 55344471.70896122, 52774122.23749314, ...,
#          53762114.53211453, 48129312.73357518, 56432872.89956613]]),
#  'trend': array([[46453743.62184638, 48522452.4055693 , 48126179.99713695, ...,
#          48094480.45284843, 47896351.35257344, 46059707.19645123],
#         [46397116.24557276, 48633274.51621866, 47737591.59588197, ...,
#          48117138.12765974, 47669816.83244784, 46138374.95919398],
#         [46390320.96041993, 48646573.16949658, 47690960.98773137, ...,
#          48119857.04863709, 47642632.69003277, 46147815.09072312],
#         ...,
#         [47648333.79478344, 49149121.60827626, 47558702.252578  , ...,
#          46475504.62784849, 47419132.40441156, 45147131.82784645],
#         [47669749.50232614, 49232033.06905769, 47545197.73334479, ...,
#          46426770.38102242, 47418914.88064871, 45026140.42899898],
#         [47744704.47872562, 49522223.18179269, 47497931.91602854, ...,
#          46256200.51713117, 47418153.54747873, 44602670.53303289]])}

# %%
sns.distplot(s['yhat'][3,:])

# %%
import numpy as np

# %%
plt.plot(np.quantile(s['yhat'], [0.01, 0.05, 0.2, 0.5, 0.8, 0.95, 0.99], axis=1).T);

# %%
model.plot_components(forecast);
model.plot(forecast);

# %%
9 + 7.5
# Out:
# 16.5

# %%
sales.groupby('Date').sum().plot(y='Weekly_Sales')

# %%
def use_model(modelname, force_compile=False):
    import pickle
    
    model_file = pkg_resources.resource_filename('fbprophet', f'stan_model/{modelname}.pkl')
    
    class KandiBackend(models.PyStanBackend):
        @staticmethod
        def build_model(target_dir, model_dir):
            import pystan
            model_name = modelname
            target_name = f'{modelname}.pkl'
            with open(os.path.join(model_dir, model_name)) as f:
                model_code = f.read()
            sm = pystan.StanModel(model_code=model_code)
            with open(os.path.join(target_dir, target_name), 'wb') as f:
                pickle.dump(sm, f, protocol=pickle.HIGHEST_PROTOCOL)
        
        def load_model(self):
            """Load compiled Stan model"""
            with open(model_file, 'rb') as f:
                return pickle.load(f)
            
    if force_compile or not os.path.exists(model_file):
        KandiBackend.build_model(Path(model_file).parent, Path(fbprophet.__path__[0]).parent / 'stan' / 'unix')
        
    return KandiBackend

# %%
backend = use_model('prophet_log_lik.stan', force_compile=True)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_1cd938a03a9adf92e302b040f6c9882e NOW.

# %%
dir(backend)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  'build_model',
#  'fit',
#  'get_type',
#  'load_model',
#  'sampling']

# %%
pkg_resources.resource_filename('fbprophet', '')
# Out:
# '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/fbprophet'

# %%
fbprophet.Prophet()

# %%
model.uncertainty_samples
# Out:
# 1000

# %%
dir(fbprophet)
# Out:
# ['Prophet',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'diagnostics',
#  'models',
#  'plot']

# %%
Path(fbprophet.__path__[0]).parent / 'stan'
# Out:
# True

# %%
n_points = 100
x = np.linspace(0, 1, num=n_points)
y = 0.3*x + 2 + np.random.normal(scale=0.1, size=n_points)
ds = pd.date_range(start='2020-1-1', periods=n_points, freq='D')
df = pd.DataFrame({'ds':ds, 'y':y})

# %%
plt.scatter(x, y)

# %%
sim_model = fbprophet.Prophet(mcmc_samples=500, yearly_seasonality=False, weekly_seasonality=False, n_changepoints=1)

# %%
sim_fit = sim_model.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
pred = sim_fit.predict()

# %%
ll = sim_fit.params['log_lik']

# %%
m = ll.sum(axis=1).mean()

# %%
ll.sum(axis=1).var()*2
# Out:
# 3.252424567740876

# %%
ll.sum(axis=1).mean()
# Out:
# 179.6977476262117

# %%
2*(181.2843356758574 - 179.6977476262117)
# Out:
# 3.173176099291368

# %%
log_lik_bayes_theta(sim_fit)
# Out:
# 181.2843356758574

# %%
p_dic(sim_fit)
# Out:
# 3.173176099291368

# %%
sim_fit.plot(pred);

# %%
compare_models([sim_model], df, no_fit=True)
# Out:
# Evaluating AIC
# -354.6694285220702
#
# Evaluating DIC
# 1800.1506523614082
#
# Evaluating WAIC2
# -348.98480334903223
#
# Evaluating p_dic
# -356.22231915313193
#
# Evaluating p_waic2
# 6.842312586518971

# %%
sim_model.params['trend'].shape
# Out:
# (1000, 100)

# %%
p_dic(sim_fit)
# Out:
# 3.173176099291368

# %%
p_dic_alt(sim_fit)
# Out:
# 3.252424567740876

# %%
dic(sim_fit)
# Out:
# -356.22231915313205

# %%
dic_alt(sim_fit)
# Out:
# -356.063822216233

# %%
sim_model.params.keys()
# Out:
# dict_keys(['k', 'm', 'delta', 'sigma_obs', 'beta', 'trend', 'mu', 'log_lik'])

# %%
data1[['ds', 'Temperature']].groupby(data1['ds'].dt.year).mean()
# Out:
#       Temperature
# ds
# 2010    67.497500
# 2011    67.658269
# 2012    69.994419

# %%
y1 = data1[data1['ds'].dt.year == 2011]

# %%
y1['ds'].dt.dayofyear
# Out:
# 48      7
# 49     14
# 50     21
# 51     28
# 52     35
# 53     42
# 54     49
# 55     56
# 56     63
# 57     70
# 58     77
# 59     84
# 60     91
# 61     98
# 62    105
# 63    112
# 64    119
# 65    126
# 66    133
# 67    140
# 68    147
# 69    154
# 70    161
# 71    168
# 72    175
# 73    182
# 74    189
# 75    196
# 76    203
# 77    210
# 78    217
# 79    224
# 80    231
# 81    238
# 82    245
# 83    252
# 84    259
# 85    266
# 86    273
# 87    280
# 88    287
# 89    294
# 90    301
# 91    308
# 92    315
# 93    322
# 94    329
# 95    336
# 96    343
# 97    350
# 98    357
# 99    364
# Name: ds, dtype: int64

# %%
y1['Temperature'].interpolate()
# Out:
# 48    48.27
# 49    35.40
# 50    44.04
# 51    43.83
# 52    42.27
# 53    36.39
# 54    57.36
# 55    62.90
# 56    59.58
# 57    53.56
# 58    62.76
# 59    69.97
# 60    59.17
# 61    67.84
# 62    71.27
# 63    72.99
# 64    72.03
# 65    64.61
# 66    75.64
# 67    67.63
# 68    77.72
# 69    83.00
# 70    83.13
# 71    86.41
# 72    83.58
# 73    85.55
# 74    85.83
# 75    88.54
# 76    85.77
# 77    86.83
# 78    91.65
# 79    90.76
# 80    89.94
# 81    87.96
# 82    87.83
# 83    76.00
# 84    79.94
# 85    75.80
# 86    79.69
# 87    69.31
# 88    71.74
# 89    63.71
# 90    66.57
# 91    54.98
# 92    59.11
# 93    62.25
# 94    60.14
# 95    48.91
# 96    43.93
# 97    51.63
# 98    47.96
# 99    44.55
# Name: Temperature, dtype: float64

# %%
yearly = pd.DataFrame({'d': range(1, 367), 't': np.NaN}).set_index('d')

# %%
yearly.loc[y1['ds'].dt.dayofyear, 't'] = y1['Temperature'].values

# %%
yearly.head(30)
# Out:
#         t
# d
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7   48.27
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14  35.40
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21  44.04
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28  43.83
# 29    NaN
# 30    NaN

# %%
yearly.interpolate()
# Out:
#             t
# d
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7   48.270000
# 8   46.431429
# 9   44.592857
# 10  42.754286
# 11  40.915714
# 12  39.077143
# 13  37.238571
# 14  35.400000
# 15  36.634286
# 16  37.868571
# 17  39.102857
# 18  40.337143
# 19  41.571429
# 20  42.805714
# 21  44.040000
# 22  44.010000
# 23  43.980000
# 24  43.950000
# 25  43.920000
# 26  43.890000
# 27  43.860000
# 28  43.830000
# 29  43.607143
# 30  43.384286
